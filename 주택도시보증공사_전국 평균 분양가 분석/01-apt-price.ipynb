# %% [markdown]
# # data 폴더에 데이터셋 확인
#
# - 데이터 분석을 시작하기 전에 데이터 셋을 다운받아 저장해봅시다.
# - 데이터 셋을 data 폴더에 옮기고 확인해봅시다.

# %%
# %ls data
# Out:
#  D 드라이브의 볼륨: 새 볼륨
#  볼륨 일련 번호: 2C11-EAC0
#
#  D:\github\python-Public_Data_Analysis\주택도시보증공사_전국 평균 분양가 분석\data 디렉터리
#
# 2022-09-06  오전 11:18    <DIR>          .
# 2022-09-19  오전 09:20    <DIR>          ..
# 2020-03-05  오전 07:28             2,163 전국 평균 분양가격(2013년 9월부터 2015년 8월까지).csv
# 2020-03-05  오전 07:28           162,510 주택도시보증공사_전국 평균 분양가격(2019년 12월).csv
#                2개 파일             164,673 바이트
#                2개 디렉터리  759,125,536,768 바이트 남음

# %% [markdown]
# # 데이터 로드하기 & 전처리 하기
# - 우선, 데이터를 로드해봅시다.

# %% [markdown]
# ## 주택도시보증공사 전국 평균 분양가격 2019년

# %% [markdown]
# ### 필요한 라이브러리 불러오기
# - 우선 엑셀과 비슷한 pandas를 import 해줍시다.

# %%
import pandas as pd

# %% [markdown]
# ### 데이터를 로드하고, 행과 열을 출력하기
# - 아까 전 data 폴더에 저장한 csv 파일을 불러오고, df_last에 저장해봅시다.
# - 인코딩 에러가 나서, 추가로 **CP949**로 인코딩을 진행합시다.
# - shape 메서드를 이용해서, 해당 csv에 **행**과 **열**을 출력해봅시다.

# %%
df_last = pd.read_csv("data/주택도시보증공사_전국 평균 분양가격(2019년 12월).csv", encoding="CP949")
df_last.shape
# Out:
# (4335, 5)

# %% [markdown]
# ### 데이터 미리보기
# - 불러온 데이터를 **head**와 **tail**로 미리 봐봅시다.

# %%
# head로 보기
df_last.head()
# Out:
#   지역명               규모구분    연도   월 분양가격(㎡)
# 0  서울                 전체  2015  10    5841
# 1  서울         전용면적 60㎡이하  2015  10    5652
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4  서울        전용면적 102㎡초과  2015  10    5879

# %%
# tail로 보기
df_last.tail()
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)
# 4330  제주                 전체  2019  12    3882
# 4331  제주         전용면적 60㎡이하  2019  12     NaN
# 4332  제주   전용면적 60㎡초과 85㎡이하  2019  12    3898
# 4333  제주  전용면적 85㎡초과 102㎡이하  2019  12     NaN
# 4334  제주        전용면적 102㎡초과  2019  12    3601

# %% [markdown]
# ## 주택도시보증공사 전국 평균 분양가격 2013년 ~ 2015년

# %% [markdown]
# ### 데이터를 로드하고, 행과 열을 출력하기
# - 2019년과 같은 방식으로 df_first에 데이터를 로드하고 행과 열을 출력해봅시다.

# %%
df_first = pd.read_csv("data/전국 평균 분양가격(2013년 9월부터 2015년 8월까지).csv", encoding="CP949")
df_first.shape
# Out:
# (17, 22)

# %% [markdown]
# ### 데이터 미리보기
# - 불러온 데이터를 **head**와 **tail**로 미리 봐봅시다.

# %%
# head로 보기
df_first.head()
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
# 1  부산      8111     8111     9078     8965     9402     9501     9453
# 2  대구      8080     8080     8077     8101     8267     8274     8360
# 3  인천     10204    10204    10408    10408    10000     9844    10058
# 4  광주      6098     7326     7611     7346     7346     7523     7659
#
#    2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 0    18742    19274  ...     20242     20269    20670    20670    19415
# 1     9457     9411  ...      9208      9208     9204     9235     9279
# 2     8360     8370  ...      8439      8253     8327     8416     8441
# 3     9974     9973  ...     10020     10020    10017     9876     9876
# 4     7612     7622  ...      7752      7748     7752     7756     7861
#
#    2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    18842    18367    18374    18152    18443
# 1     9327     9345     9515     9559     9581
# 2     8446     8568     8542     8542     8795
# 3     9938    10551    10443    10443    10449
# 4     7914     7877     7881     8089     8231
#
# [5 rows x 22 columns]

# %%
# tail로 보기
df_first.tail()
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 12  전북      6282     6281     5946     5966     6277     6306     6351
# 13  전남      5678     5678     5678     5696     5736     5656     5609
# 14  경북      6168     6168     6234     6317     6412     6409     6554
# 15  경남      6473     6485     6502     6610     6599     6610     6615
# 16  제주      7674     7900     7900     7900     7900     7900     7914
#
#     2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 12     6319     6436  ...      6583      6583     6583     6583     6542
# 13     5780     5685  ...      5768      5784     5784     5833     5825
# 14     6556     6563  ...      6881      6989     6992     6953     6997
# 15     6613     6606  ...      7125      7332     7592     7588     7668
# 16     7914     7914  ...      7724      7739     7739     7739     7826
#
#     2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 12     6551     6556     6601     6750     6580
# 13     5940     6050     6243     6286     6289
# 14     7006     6966     6887     7035     7037
# 15     7683     7717     7715     7723     7665
# 16     7285     7285     7343     7343     7343
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 데이터 요약하기
# - 지금까지 불러온 데이터를 요약시켜 봅시다.
# - info 메서드를 사용하면 됩니다.

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 169.5+ KB

# %% [markdown]
# ##  결측치 확인하기
# - df_last에 경우 위에서 보면 **NaN**이라는 값이 보일것이다.
# - isnull 혹은 isna 메서드를 사용하면 결측치가 있는지 여부를 확인할 수 있다.
# - sum 메서드를 사용하면 결측치의 수를 구할 수가 있다.
# - 이걸 한번 확인해보자.

# %%
df_last.isnull().sum() # isnull() 사용
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    277
# dtype: int64

# %%
 df_last.isna().sum() # isna() 사용
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    277
# dtype: int64

# %% [markdown]
# ## 데이터 타입 변경
# - 위 데이터 요약을 확인하면 분양 가격이 Object로 되어있는 것을 확인할 수 있다.
# - 알고는 있겠지만 문자열 타입은 계산을 할 수 없다. 그래서 우리는 이것을 **수치 데이터**로 변환시켜야 한다.
# - 결측치가 섞여 있을 때는 변환이 제대로 되지 않는 문제가 발생한다.
# - 그래서 **pd.to_numeric**을 통해 데이터의 타입을 변환할것이다.
# - 한번 실습해보자.

# %%
df_last['분양가격'] = pd.to_numeric(df_last['분양가격(㎡)'], errors="coerce")
df_last["분양가격"].head(1)
# Out:
# 0    5841.0
# Name: 분양가격, dtype: float64

# %% [markdown]
# ## 평당분양가격 구하기
# - df_first같은 경우, 평당분양가격 기준으로 되어있지만 df_last는 분양가격을 기준으로 되어있다.
# - df_last에 분양가격기준을 평당분양가격기준으로 보기 위해 3.3을 곱해서 평당분양가격 컬럼을 추가해 보자.

# %%
df_last['평당분양가격'] = df_last['분양가격'] * 3.3
df_last
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)    분양가격   평당분양가격
# 0     서울                 전체  2015  10    5841  5841.0  19275.3
# 1     서울         전용면적 60㎡이하  2015  10    5652  5652.0  18651.6
# 2     서울   전용면적 60㎡초과 85㎡이하  2015  10    5882  5882.0  19410.6
# 3     서울  전용면적 85㎡초과 102㎡이하  2015  10    5721  5721.0  18879.3
# 4     서울        전용면적 102㎡초과  2015  10    5879  5879.0  19400.7
# ...   ..                ...   ...  ..     ...     ...      ...
# 4330  제주                 전체  2019  12    3882  3882.0  12810.6
# 4331  제주         전용면적 60㎡이하  2019  12     NaN     NaN      NaN
# 4332  제주   전용면적 60㎡초과 85㎡이하  2019  12    3898  3898.0  12863.4
# 4333  제주  전용면적 85㎡초과 102㎡이하  2019  12     NaN     NaN      NaN
# 4334  제주        전용면적 102㎡초과  2019  12    3601  3601.0  11883.3
#
# [4335 rows x 7 columns]

# %% [markdown]
# ## 분양가격 요약하기
# - 분양가격을 요약하여 봅시다.

# %% [markdown]
# ### info로 요약하기.

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
#  5   분양가격     3957 non-null   float64
#  6   평당분양가격   3957 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 237.2+ KB

# %% [markdown]
# ### 변경 전 분양가격 컬럼을 요약하기.
# - describe 메소드로 요약이 가능하다.

# %%
df_last['분양가격(㎡)'].describe()
# Out:
# count     4058
# unique    1753
# top       2221
# freq        17
# Name: 분양가격(㎡), dtype: object

# %% [markdown]
# ### 수치데이터로 변경된 분양가격 컬럼을 요약하기
# - 이 경우, 더 자세하게 나온다.

# %%
df_last['분양가격'].describe()
# Out:
# count     3957.000000
# mean      3238.128633
# std       1264.309933
# min       1868.000000
# 25%       2441.000000
# 50%       2874.000000
# 75%       3561.000000
# max      12728.000000
# Name: 분양가격, dtype: float64

# %% [markdown]
# ## 규모구분을 전용면적 컬럼으로 바꾸기
# - 규모구분 컬럼을 보면 전용면적에 대한 내용이 포함되어 있다.
# - 전용면적이라는 문구가 공통적으로 들어가고, 규모부분보다는 전용면적이 좀 더 직관적이다.
# - 따라서, 전용면적이라는 컬럼을 만들어주고 기존 규모구분의 값에서 전용면적, 초과, 이하 등의 문구를 빼고 간결하게 만들어보자.
# - str과 replace 기능을 사용하면 된다.

# %%
df_last["규모구분"].unique()
# Out:
# array(['전체', '전용면적 60㎡이하', '전용면적 60㎡초과 85㎡이하', '전용면적 85㎡초과 102㎡이하',
#        '전용면적 102㎡초과'], dtype=object)

# %%
df_last["전용면적"] = df_last["규모구분"].str.replace("전용면적", "")
df_last["전용면적"] = df_last["전용면적"].str.replace("초과", " ~")
df_last["전용면적"] = df_last["전용면적"].str.replace("이하", "")
df_last["전용면적"] = df_last["전용면적"].str.replace(" ", "").str.strip()
df_last["전용면적"]
# Out:
# 0             전체
# 1            60㎡
# 2        60㎡~85㎡
# 3       85㎡~102㎡
# 4          102㎡~
#           ...
# 4330          전체
# 4331         60㎡
# 4332     60㎡~85㎡
# 4333    85㎡~102㎡
# 4334       102㎡~
# Name: 전용면적, Length: 4335, dtype: object

# %% [markdown]
# ## 필요없는 컬럼 제거하기
# - drop을 통해 전처리 해준 컬럼을 제거해보자.
# - 데이터프레임과 관련된 메소드에는 axis 옵션이 필요할 때가 있다.
#   - axis는 **행**과 **열**중 어떤 기준으로 처리할 지 물어보는 옵션이다.
# - 기본적으로는 0(행)으로 되어있다. ( 1은 열 )
# - 필요없는 컬럼을 삭제하면 그만큼 사용하는 메모리의 사용량이 줄어든다

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
#  5   분양가격     3957 non-null   float64
#  6   평당분양가격   3957 non-null   float64
#  7   전용면적     4335 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 271.1+ KB

# %%
df_last = df_last.drop(["규모구분", "분양가격(㎡)"], axis=1)

# %%
df_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역명     4335 non-null   object
#  1   연도      4335 non-null   int64
#  2   월       4335 non-null   int64
#  3   분양가격    3957 non-null   float64
#  4   평당분양가격  3957 non-null   float64
#  5   전용면적    4335 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 203.3+ KB

# %% [markdown]
# # 데이터 집계하기
# - 여러가지 방법이 있겠지만, 여기선 2가지 방법을 소개한다.

# %% [markdown]
# ## groupby로 데이터 집계하기
# - groupby를 사용해서 데이터를 그룹화해서 연산을 해봅시다.

# %%
# 지역명으로 분양가격의 평균을 구하라.
df_last.groupby(["지역명"])["평당분양가격"].mean() # 평균
df_last.groupby(["지역명"])["평당분양가격"].sum() # 합계
df_last.groupby(["지역명"])["평당분양가격"].max() # 최고가
df_last.groupby(["지역명"])["평당분양가격"].min() # 최솟값
df_last.groupby(["지역명"])["평당분양가격"].describe() # 요약
# Out:
#      count          mean          std      min        25%       50%  \
# 지역명
# 강원   242.0   7890.750000  1044.359840   6639.6   7165.950   7581.75
# 경기   250.0  13356.895200  1969.310711  10160.7  11729.025  13168.65
# 경남   247.0   9268.778138  1356.695327   7260.0   8233.500   9187.20
# 경북   241.0   8376.536515   850.823275   6949.8   7728.600   8335.80
# 광주   201.0   9951.535821  1506.593261   7428.3   9068.400   9527.10
# 대구   242.0  11980.895455  2018.395637   8259.9  10399.950  11904.75
# 대전   198.0  10253.333333  2245.370020   8002.5   8580.000   9401.70
# 부산   250.0  12087.121200  1447.322754   9669.0  10709.325  12338.70
# 서울   250.0  23599.976400  3969.953218  16701.3  21318.825  22497.75
# 세종   237.0   9796.516456  1096.551246   8487.6   8906.700   9197.10
# 울산   149.0  10014.902013   899.543667   7992.6   9484.200  10127.70
# 인천   246.0  11915.320732  1642.963530   9537.0  10808.325  11378.40
# 전남   248.0   7565.316532   773.929820   6289.8   7098.300   7585.05
# 전북   248.0   7724.235484   868.364876   6270.0   7248.450   7659.30
# 제주   219.0  11241.276712  2351.630010   7342.5   9929.700  10787.70
# 충남   239.0   8233.651883   741.954128   6926.7   7585.050   8134.50
# 충북   250.0   7634.655600   796.759331   6164.4   6969.600   7543.80
#
#            75%      max
# 지역명
# 강원    8281.350  11873.4
# 경기   14600.025  18711.0
# 경남    9698.700  14199.9
# 경북    8824.200  11408.1
# 광주   10800.900  16107.3
# 대구   13330.350  17021.4
# 대전   11615.175  16094.1
# 부산   12972.300  15255.9
# 서울   25072.575  42002.4
# 세종   10388.400  12972.3
# 울산   10474.200  11860.2
# 인천   12480.600  17120.4
# 전남    7923.300  10074.9
# 전북    8241.750  10071.6
# 제주   12553.200  18024.6
# 충남    8768.100  10563.3
# 충북    8250.000   9421.5

# %%
# 전용면적으로 평당분양가격의 평균을 구하라.
df_last.groupby(["전용면적"])["평당분양가격"].mean()
# Out:
# 전용면적
# 102㎡~       11517.705634
# 60㎡         10375.137421
# 60㎡~85㎡     10271.040071
# 85㎡~102㎡    11097.599573
# 전체          10276.086207
# Name: 평당분양가격, dtype: float64

# %%
# 지역명, 전용면적으로 평당분양가격의 평균을 구하라.
df_last.groupby(["전용면적", "지역명"])["평당분양가격"].mean().unstack().round()
# Out:
# 지역명           강원       경기       경남      경북       광주       대구       대전  \
# 전용면적
# 102㎡~     8311.0  14772.0  10358.0  9157.0  11042.0  13087.0  14877.0
# 60㎡       7567.0  13252.0   8689.0  7883.0   9431.0  11992.0   9176.0
# 60㎡~85㎡   7486.0  12524.0   8619.0  8061.0   9911.0  11779.0   9711.0
# 85㎡~102㎡  8750.0  13678.0  10018.0  8774.0   9296.0  11141.0   9037.0
# 전체        7478.0  12560.0   8659.0  8079.0   9904.0  11771.0   9786.0
#
# 지역명            부산       서울       세종       울산       인천      전남      전북  \
# 전용면적
# 102㎡~     13208.0  23446.0  10107.0   9974.0  14362.0  8168.0  8194.0
# 60㎡       11354.0  23213.0   9324.0   9202.0  11241.0  7210.0  7610.0
# 60㎡~85㎡   11865.0  22787.0   9775.0  10503.0  11384.0  7269.0  7271.0
# 85㎡~102㎡  12073.0  25944.0   9848.0   8861.0  11528.0  7909.0  8276.0
# 전체        11936.0  22610.0   9805.0  10493.0  11257.0  7284.0  7293.0
#
# 지역명            제주      충남      충북
# 전용면적
# 102㎡~     10523.0  8689.0  8195.0
# 60㎡       14022.0  7911.0  7103.0
# 60㎡~85㎡   10621.0  7819.0  7264.0
# 85㎡~102㎡  10709.0  9120.0  8391.0
# 전체        10785.0  7815.0  7219.0

# %%
# 연도, 지역명으로 평당분양가격의 평균을 구하라.
g = df_last.groupby(["지역명", "연도"])["평당분양가격"].mean()
g.unstack().transpose()
# Out:
# 지역명            강원        경기            경남           경북            광주  \
# 연도
# 2015  7188.060000  11060.94   8459.220000  7464.160000   7916.700000
# 2016  7162.903846  11684.97   8496.730000  7753.405000   9190.683333
# 2017  7273.560000  12304.98   8786.760000  8280.800000   9613.977551
# 2018  8219.255000  14258.42   9327.670000  8680.776923   9526.953333
# 2019  8934.475000  15665.54  10697.615789  9050.250000  12111.675000
#
# 지역명             대구            대전         부산         서울            세종  \
# 연도
# 2015   9018.900000   8190.600000  10377.400  20315.680   8765.020000
# 2016  10282.030000   8910.733333  10743.535  21753.435   8857.805000
# 2017  12206.700000   9957.158491  11560.680  21831.060   9132.505556
# 2018  12139.252632  10234.106667  12889.965  23202.245  10340.463158
# 2019  14081.650000  12619.200000  13537.865  28286.830  11299.394118
#
# 지역명             울산            인천           전남           전북            제주  \
# 연도
# 2015   9367.600000  10976.020000  6798.880000  7110.400000   7951.075000
# 2016   9582.574138  11099.055000  6936.600000  6906.625000   9567.480000
# 2017  10666.935714  11640.600000  7372.920000  7398.973585  12566.730000
# 2018  10241.400000  11881.532143  7929.845000  8174.595000  11935.968000
# 2019  10216.250000  13249.775000  8219.275862  8532.260000  11828.469231
#
# 지역명            충남        충북
# 연도
# 2015  7689.880000  6828.800
# 2016  7958.225000  7133.335
# 2017  8198.422222  7473.120
# 2018  8201.820000  8149.295
# 2019  8748.840000  7970.875

# %% [markdown]
# ## pivot table로 데이터 집계하기
# - groupby에서 했던 작업을 피봇 테이블로도 해보자!

# %%
pd.pivot_table(df_last, index=["지역명"], values=['평당분양가격'], aggfunc="sum")
# Out:
#         평당분양가격
# 지역명
# 강원   1909561.5
# 경기   3339223.8
# 경남   2289388.2
# 경북   2018745.3
# 광주   2000258.7
# 대구   2899376.7
# 대전   2030160.0
# 부산   3021780.3
# 서울   5899994.1
# 세종   2321774.4
# 울산   1492220.4
# 인천   2931168.9
# 전남   1876198.5
# 전북   1915610.4
# 제주   2461839.6
# 충남   1967842.8
# 충북   1908663.9

# %%
# df_last.groupby(["전용면적"])["평당분양가격"].mean()
pd.pivot_table(df_last, index=["전용면적"], values=["평당분양가격"])
# Out:
#                 평당분양가격
# 전용면적
# 102㎡~     11517.705634
# 60㎡       10375.137421
# 60㎡~85㎡   10271.040071
# 85㎡~102㎡  11097.599573
# 전체        10276.086207

# %%
# df_last.groupby(["전용면적", "지역명"])["평당분양가격"].mean().unstack().round()
df_last.pivot_table(index=["전용면적"], columns = "지역명", values="평당분양가격")
# Out:
# 지역명                강원         경기            경남           경북            광주  \
# 전용면적
# 102㎡~     8311.380000  14771.790  10358.363265  9157.302000  11041.532432
# 60㎡       7567.098000  13251.744   8689.175000  7883.172000   9430.666667
# 60㎡~85㎡   7485.588000  12523.566   8618.676000  8061.372000   9910.692000
# 85㎡~102㎡  8749.557143  13677.774  10017.612000  8773.814634   9296.100000
# 전체        7477.536000  12559.602   8658.672000  8078.532000   9903.630000
#
# 지역명                 대구            대전         부산         서울            세종  \
# 전용면적
# 102㎡~     13087.338000  14876.871429  13208.250  23446.038  10106.976000
# 60㎡       11992.068000   9176.475000  11353.782  23212.794   9323.927027
# 60㎡~85㎡   11778.690000   9711.372000  11864.820  22786.830   9775.458000
# 85㎡~102㎡  11140.642857   9037.430769  12072.588  25943.874   9847.926000
# 전체        11771.298000   9786.018000  11936.166  22610.346   9805.422000
#
# 지역명                 울산            인천         전남          전북            제주  \
# 전용면적
# 102㎡~      9974.448000  14362.030435  8168.4900  8193.57000  10522.787234
# 60㎡        9202.106897  11241.318000  7210.1700  7609.93200  14022.221053
# 60㎡~85㎡   10502.531707  11384.406000  7269.2400  7271.35200  10621.314000
# 85㎡~102㎡   8861.007692  11527.560000  7908.8625  8275.78125  10709.082353
# 전체        10492.712195  11257.026000  7283.5620  7292.60400  10784.994000
#
# 지역명                충남        충북
# 전용면적
# 102㎡~     8689.169388  8195.352
# 60㎡       7911.156000  7103.118
# 60㎡~85㎡   7818.954000  7264.488
# 85㎡~102㎡  9120.045000  8391.306
# 전체        7815.324000  7219.014

# %%
# 연도, 지역명으로 평당분양가격의 평균을 구하라
df_last.pivot_table(index=["연도"], columns = "지역명", values="평당분양가격")
# Out:
# 지역명            강원        경기            경남           경북            광주  \
# 연도
# 2015  7188.060000  11060.94   8459.220000  7464.160000   7916.700000
# 2016  7162.903846  11684.97   8496.730000  7753.405000   9190.683333
# 2017  7273.560000  12304.98   8786.760000  8280.800000   9613.977551
# 2018  8219.255000  14258.42   9327.670000  8680.776923   9526.953333
# 2019  8934.475000  15665.54  10697.615789  9050.250000  12111.675000
#
# 지역명             대구            대전         부산         서울            세종  \
# 연도
# 2015   9018.900000   8190.600000  10377.400  20315.680   8765.020000
# 2016  10282.030000   8910.733333  10743.535  21753.435   8857.805000
# 2017  12206.700000   9957.158491  11560.680  21831.060   9132.505556
# 2018  12139.252632  10234.106667  12889.965  23202.245  10340.463158
# 2019  14081.650000  12619.200000  13537.865  28286.830  11299.394118
#
# 지역명             울산            인천           전남           전북            제주  \
# 연도
# 2015   9367.600000  10976.020000  6798.880000  7110.400000   7951.075000
# 2016   9582.574138  11099.055000  6936.600000  6906.625000   9567.480000
# 2017  10666.935714  11640.600000  7372.920000  7398.973585  12566.730000
# 2018  10241.400000  11881.532143  7929.845000  8174.595000  11935.968000
# 2019  10216.250000  13249.775000  8219.275862  8532.260000  11828.469231
#
# 지역명            충남        충북
# 연도
# 2015  7689.880000  6828.800
# 2016  7958.225000  7133.335
# 2017  8198.422222  7473.120
# 2018  8201.820000  8149.295
# 2019  8748.840000  7970.875

# %% [markdown]
# # 최근 데이터 시각화 하기
# - 2019년 데이터를 시각화 해보자!

# %% [markdown]
# ## 데이터 시각화를 위한 폰트설정
# - 우선 데이터를 시각화하기 위해서 폰트를 설정해야 한다.
# - 폰트는 "맑은 고딕"을 사용하자. ( 애플은 애플고딕 )

# %%
import matplotlib.pyplot as plt
plt.rc("font", family="Malgun Gothic")

# %% [markdown]
# ## Pandas로 시각화 하기 - 선그래프 & 막대그래프
# - pandas 라이브러리의 plot을 활용하면 다양한 그래프를 그릴 수 있다.
# - seaborn을 사용했을 때보다 pandas를 사용해서 시각화를 했을 경우, 미리 계산을 하고 그리기 때문에 속도가 좀 더 빠르다.

# %%
# 지역명으로 분양가격의 평균을 구하고 선 그래프로 시각화하라
g = df_last.groupby(["지역명"])["평당분양가격"].mean().sort_values(ascending=False)
g.plot.bar(rot=0, figsize=(10, 3))
# Out:
# <AxesSubplot:xlabel='지역명'>

# %%
# 전용면적으로 분양가격의 평균을 구하고 막대그래프로 시각화 합니다.
g = df_last.groupby(["전용면적"])["평당분양가격"].mean()
g.plot.bar(rot=0, figsize=(10, 3))
# Out:
# <AxesSubplot:xlabel='전용면적'>

# %%
# 연도별 분양가격의 평균을 구하고 막대그래프로 시각화 합니다.
g = df_last.groupby(["연도"])["평당분양가격"].mean()
g.plot.bar(rot=0, figsize=(10, 3))
# Out:
# <AxesSubplot:xlabel='연도'>

# %% [markdown]
# ## box-and-whisker plot | Diagram
# - 가공되지 않은 자료 그대로를 이용하여 그린것이 아닌, 자료로부터 얻어낸 통계량인 5가지 요약수치로 그린다.
# - 5가지 요약수치란? **기술통계학**에서 자료의 정보를 알려주는 아래의 다섯 가지 수치를 의미한다.
#   1. 최솟값
#   2. 제 1사분위수
#   3. 제 2사분위수, 즉 중앙값
#   4. 제 3사분위수
#   5. 최댓값

# %%
df_last.pivot_table(index="월", columns="연도", values="평당분양가격").plot.box()
# Out:
# <AxesSubplot:>

# %%
p = df_last.pivot_table(index="연도", columns="지역명", values="평당분양가격")
p.plot.box(figsize=(15, 3), rot=40)
# Out:
# <AxesSubplot:>

# %%
p.plot(figsize=(15, 3), rot=40)
# Out:
# <AxesSubplot:xlabel='연도'>

# %% [markdown]
# ## Seaborn으로 시각화 하기
# - 위 pandas보다는 느리지만, 디자인이 예쁘고, 여러가지 기능이 달려 있어서 좋다.
# - Seaborn으로 시각화를 해보자

# %%
import seaborn as sns

# %%
# 지역별 평당분양가격
plt.figure(figsize=(10, 3))
sns.barplot(data=df_last, x="지역명", y="평당분양가격",)
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
# 연도별 평당분양가격
sns.barplot(data=df_last, x="연도", y="평당분양가격",)
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
# 위 그래프를 line으로 그려봅시다.
plt.figure(figsize=(10, 3))
sns.lineplot(data=df_last, x="연도", y="평당분양가격", hue="지역명")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# relplot로 그려봅시다.
sns.relplot(data=df_last, x="연도", y="평당분양가격", hue="지역명" , kind="line", col="지역명", col_wrap = 4, ci = None)

# %%
# catplot로 그려봅시다.
sns.catplot(data=df_last, x="연도", y="평당분양가격", kind="bar", col="지역명", col_wrap = 4)

# %% [markdown]
# ## Seaborn으로 boxplot, violinplot 그리기
# - 아까 봤었던 boxplot과 추가로 violinplot를 그려보자.

# %%
# boxplot로 그려보자.
sns.boxplot(data=df_last, x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
# Violinplot로 그려보자.
sns.violinplot(data=df_last, x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %% [markdown]
# ## lmplot과 swarmplot
# - Seaborn으로 lmport과 swarmplot를 그려보자.

# %%
# lmplot으로 그려보자.
sns.regplot(data=df_last, x="연도", y="평당분양가격")
# hue를 이용하여 전용면적을 표현해보자.
sns.lmplot(data=df_last, x="연도", y="평당분양가격", hue="전용면적", col="전용면적", col_wrap=3)

# %%
 # 연도별 평당분양가격을 swarmplot으로 그려보자
plt.figure(figsize=(15, 3))
sns.swarmplot(data=df_last, x="연도", y="평당분양가격", hue="전용면적")
# Out:
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 73.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 62.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 62.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 60.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %% [markdown]
# ## 이상치 보기

# %%
# 평당가격값의 최대값을 구해서 max_pricee라는 변수에 담자.
max_price = df_last["평당분양가격"].max()
max_price
# Out:
# 42002.399999999994

# %%
# 특히 높은 데이터를 가져와보자.
df_last[df_last['평당분양가격'] == max_price]
# Out:
#      지역명    연도   월     분양가격   평당분양가격      전용면적
# 3743  서울  2019   6  12728.0  42002.4  85㎡~102㎡
# 3828  서울  2019   7  12728.0  42002.4  85㎡~102㎡
# 3913  서울  2019   8  12728.0  42002.4  85㎡~102㎡
# 3998  서울  2019   9  12728.0  42002.4  85㎡~102㎡
# 4083  서울  2019  10  12728.0  42002.4  85㎡~102㎡
# 4168  서울  2019  11  12728.0  42002.4  85㎡~102㎡
# 4253  서울  2019  12  12728.0  42002.4  85㎡~102㎡

# %% [markdown]
# ## 수치데이터 히스토그램 그리기
# - distplot는 결측치가 있으면 그래프를 그릴 때 오류가 생긴다.
# - 결측치가 아닌 데이터만 따로 모아서 평당분양가격을 시각화한 데이터를 만들어보자.<br>

# %%
df_last["평당분양가격"].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
price = df_last.loc[df_last["평당분양가격"].notnull(), "평당분양가격"]

# %%
#distplot으로 평당분양가격을 표현해보자.
sns.distplot(price)
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='평당분양가격', ylabel='Density'>

# %%
# sns.distplot(price, hist=False, rug=True)
sns.kdeplot(price, cumulative=True)
# Out:
# <AxesSubplot:xlabel='평당분양가격', ylabel='Density'>

# %%
# subplot으로 표현해보자.
g = sns.FacetGrid(df_last, row="지역명",
                 height = 1.7, aspect = 4)
g.map(sns.distplot, "평당분양가격", hist = False, rug = True)
# Out:
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
#pairplot
df_last_notnull = df_last.loc[df_last['평당분양가격'].notnull(), 
                          ["연도", "월", "평당분양가격", "지역명", "전용면적"]]
sns.pairplot(df_last_notnull, hue="전용면적")

# %%
# 규모구분별로 value_counts를 사용해서 데이터를 집계해보자.
df_last["전용면적"].value_counts()
# Out:
# 전체          867
# 60㎡         867
# 60㎡~85㎡     867
# 85㎡~102㎡    867
# 102㎡~       867
# Name: 전용면적, dtype: int64

# %% [markdown]
# # 2015년 8월 이전 데이터 보기

# %%
pd.options.display.max_columns = 25

# %%
df_last.head()
# Out:
#   지역명    연도   월    분양가격   평당분양가격      전용면적
# 0  서울  2015  10  5841.0  19275.3        전체
# 1  서울  2015  10  5652.0  18651.6       60㎡
# 2  서울  2015  10  5882.0  19410.6   60㎡~85㎡
# 3  서울  2015  10  5721.0  18879.3  85㎡~102㎡
# 4  서울  2015  10  5879.0  19400.7     102㎡~

# %%
df_first.head()
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
# 1  부산      8111     8111     9078     8965     9402     9501     9453
# 2  대구      8080     8080     8077     8101     8267     8274     8360
# 3  인천     10204    10204    10408    10408    10000     9844    10058
# 4  광주      6098     7326     7611     7346     7346     7523     7659
#
#    2014년7월  2014년8월  2014년9월  2014년10월  2014년11월  2014년12월  2015년1월  2015년2월  \
# 0    18742    19274    19404     19759     20242     20269    20670    20670
# 1     9457     9411     9258      9110      9208      9208     9204     9235
# 2     8360     8370     8449      8403      8439      8253     8327     8416
# 3     9974     9973     9973     10016     10020     10020    10017     9876
# 4     7612     7622     7802      7707      7752      7748     7752     7756
#
#    2015년3월  2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    19415    18842    18367    18374    18152    18443
# 1     9279     9327     9345     9515     9559     9581
# 2     8441     8446     8568     8542     8542     8795
# 3     9876     9938    10551    10443    10443    10449
# 4     7861     7914     7877     7881     8089     8231

# %%
df_first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        17 non-null     object
#  1   2013년12월  17 non-null     int64
#  2   2014년1월   17 non-null     int64
#  3   2014년2월   17 non-null     int64
#  4   2014년3월   17 non-null     int64
#  5   2014년4월   17 non-null     int64
#  6   2014년5월   17 non-null     int64
#  7   2014년6월   17 non-null     int64
#  8   2014년7월   17 non-null     int64
#  9   2014년8월   17 non-null     int64
#  10  2014년9월   17 non-null     int64
#  11  2014년10월  17 non-null     int64
#  12  2014년11월  17 non-null     int64
#  13  2014년12월  17 non-null     int64
#  14  2015년1월   17 non-null     int64
#  15  2015년2월   17 non-null     int64
#  16  2015년3월   17 non-null     int64
#  17  2015년4월   17 non-null     int64
#  18  2015년5월   17 non-null     int64
#  19  2015년6월   17 non-null     int64
#  20  2015년7월   17 non-null     int64
#  21  2015년8월   17 non-null     int64
# dtypes: int64(21), object(1)
# memory usage: 3.0+ KB

# %%
df_first.isnull().sum()
# Out:
# 지역          0
# 2013년12월    0
# 2014년1월     0
# 2014년2월     0
# 2014년3월     0
# 2014년4월     0
# 2014년5월     0
# 2014년6월     0
# 2014년7월     0
# 2014년8월     0
# 2014년9월     0
# 2014년10월    0
# 2014년11월    0
# 2014년12월    0
# 2015년1월     0
# 2015년2월     0
# 2015년3월     0
# 2015년4월     0
# 2015년5월     0
# 2015년6월     0
# 2015년7월     0
# 2015년8월     0
# dtype: int64

# %% [markdown]
# ## melt로 Tidy data 만들기
# - pandas의 melt를 사용하면 데이터의 형태를 변경할 수 있다.
# - df_first 변수에 담긴 데이터프레임은 df_last에 담겨있는 데이터프레임의 모습과 다르다.
# - 데이터를 병합하려면 같은 형태로 만들어주어야 한다.
# - melt를 사용해 열에 있는 데이터를 행으로 녹여보자.

# %%
df_first_melt = df_first.melt(id_vars="지역", var_name="기간", value_name="평당분양가격")
df_first_melt.head()
# Out:
#    지역        기간  평당분양가격
# 0  서울  2013년12월   18189
# 1  부산  2013년12월    8111
# 2  대구  2013년12월    8080
# 3  인천  2013년12월   10204
# 4  광주  2013년12월    6098

# %%
# df_first_melt 변수에 담겨진 컬럼명을 [지역명, 기간, 평당분양가격]으로 바꿔보자.
df_first_melt.columns = ["지역명", "기간", "평당분양가격"]
df_first_melt.head(1)
# Out:
#   지역명        기간  평당분양가격
# 0  서울  2013년12월   18189

# %% [markdown]
# ## 연도와 월을 분리하기
# - pandas의 string-handling을 사용하면 분리할 수 있다.

# %%
date = "2013년12월"
date
# Out:
# '2013년12월'

# %%
date.split("년") # 연도를 기준으로 텍스트 분리해보기
# Out:
# ['2013', '12월']

# %%
date.split("년")[0] # 연도 가져오기
# Out:
# '2013'

# %%
date.split("년")[-1].replace("월", "") # 월 가져오기, 월이라는 텍스트는 삭제
# Out:
# '12'

# %%
# paese_year라는 함수를 만들자.
# 연도만 반환, 반환하는 데이터는 int로
def parse_year(date):
    year = date.split("년")[0]
    return int(year)
y = parse_year(date)
type(y)
# Out:
# int

# %%
y # 함수 확인
# Out:
# 2013

# %%
# parse_month라는 함수를 만들자.
# 월만 반환, 반환하는 데이터는 int로
def parse_month(date):
    month = date.split("년")[-1].replace("월", "")
    return int(month)

# %%
parse_month(date) # 함수 확인
# Out:
# 12

# %%
# df_first_melt 변수에 담긴 데이터프레임에서 apply를 활용해 연도만 추출해서 새로운 컬럼에 담아보자.
df_first_melt["연도"] = df_first_melt["기간"].apply(parse_year)
df_first_melt.head(1)
# Out:
#   지역명        기간  평당분양가격    연도
# 0  서울  2013년12월   18189  2013

# %%
# df_first_melt 변수에 담긴 데이터프레임에서 apply를 활용해 월만 추출해서 새로운 컬럼에 담아보자.
df_first_melt["월"] = df_first_melt["기간"].apply(parse_month)
df_first_melt.head(1)
# Out:
#   지역명        기간  평당분양가격    연도   월
# 0  서울  2013년12월   18189  2013  12

# %%
# df_last와 병합을 하기 위해서는 컬럼의 이름이 같아야 한다.
# info 대신 sample을 활용해서 데이터를 미리보기 해보자.
df_last.sample()
df_first_melt.sample()
# Out:
#     지역명       기간  평당분양가격    연도  월
# 106  광주  2014년6월    7659  2014  6

# %%
df_last.columns.to_list()
# Out:
# ['지역명', '연도', '월', '분양가격', '평당분양가격', '전용면적']

# %%
cols = ["지역명", "연도", "월", "평당분양가격"]
cols
# Out:
# ['지역명', '연도', '월', '평당분양가격']

# %%
# 최근 데이터에는 "전용면적"이 있다.
# 이전 데이터에는 전용면적이 없기 때문에 전체만 사용하도록 하자.
# loc를 사용해서 전체에 해당하는 면적만 copy로 복사해서 df_last_prepare 변수에 담자.
df_last_prepare = df_last.loc[df_last["전용면적"] == "전체", cols].copy()
df_last_prepare.head(1)
# Out:
#   지역명    연도   월   평당분양가격
# 0  서울  2015  10  19275.3

# %%
# df_first__melt에서 공통된 컬럼만 가져온 뒤 copy로 복사해서 df_first_prepare 컬럼에 담자.
df_first_prepare = df_first_melt[cols].copy()
df_first_prepare.head(1)
# Out:
#   지역명    연도   월  평당분양가격
# 0  서울  2013  12   18189

# %% [markdown]
# ## concat로 데이터 합치기

# %%
df = pd.concat([df_first_prepare, df_last_prepare])
df.shape
# Out:
# (1224, 4)

# %%
df.head() # 확인
# Out:
#   지역명    연도   월   평당분양가격
# 0  서울  2013  12  18189.0
# 1  부산  2013  12   8111.0
# 2  대구  2013  12   8080.0
# 3  인천  2013  12  10204.0
# 4  광주  2013  12   6098.0

# %%
df.tail() # 확인
# Out:
#      지역명    연도   월   평당분양가격
# 4310  전북  2019  12   8144.4
# 4315  전남  2019  12   8091.6
# 4320  경북  2019  12   9616.2
# 4325  경남  2019  12  10107.9
# 4330  제주  2019  12  12810.6

# %%
# 연도별로 데이터가 몇개씩 있는지 확인해보자.
df["연도"].value_counts(sort=False)
# Out:
# 2013     17
# 2014    204
# 2015    187
# 2016    204
# 2017    204
# 2018    204
# 2019    204
# Name: 연도, dtype: int64

# %% [markdown]
# ## pivot_table 사용하기

# %%
# 연도를 인덱스로, 지역명을 컬럼으로 평당분양가격을 피봇테이블로 그려봅시다.
t = pd.pivot_table(df, index="연도", columns="지역명", values="평당분양가격").round()
t
# Out:
# 지역명       강원       경기      경남      경북       광주       대구       대전       부산  \
# 연도
# 2013  6230.0  10855.0  6473.0  6168.0   6098.0   8080.0   8321.0   8111.0
# 2014  6332.0  10509.0  6729.0  6536.0   7588.0   8286.0   8240.0   9180.0
# 2015  6831.0  10489.0  7646.0  7035.0   7956.0   8707.0   8105.0   9633.0
# 2016  7011.0  11220.0  7848.0  7361.0   8899.0  10310.0   8502.0  10430.0
# 2017  7127.0  11850.0  8120.0  7795.0   9464.0  11456.0   9045.0  11578.0
# 2018  7681.0  13186.0  9019.0  8505.0   9856.0  12076.0  10180.0  12998.0
# 2019  8142.0  14469.0  9871.0  8857.0  11823.0  13852.0  11778.0  13116.0
#
# 지역명        서울       세종       울산       인천      전남      전북       제주      충남  \
# 연도
# 2013  18189.0   7601.0   8090.0  10204.0  5678.0  6282.0   7674.0  6365.0
# 2014  18997.0   8085.0   8362.0  10075.0  5719.0  6362.0   7855.0  6682.0
# 2015  19283.0   8641.0   9273.0  10277.0  6109.0  6623.0   7465.0  7024.0
# 2016  20663.0   8860.0  10209.0  10532.0  6489.0  6418.0   9129.0  7331.0
# 2017  21376.0   9135.0  11345.0  10737.0  7188.0  7058.0  10831.0  7456.0
# 2018  22889.0  10355.0  10241.0  11274.0  7789.0  7626.0  11891.0  8013.0
# 2019  26131.0  11079.0  10022.0  12635.0  7902.0  8197.0  12138.0  8607.0
#
# 지역명       충북
# 연도
# 2013  6589.0
# 2014  6620.0
# 2015  6700.0
# 2016  6770.0
# 2017  6763.0
# 2018  7874.0
# 2019  7575.0

# %%
# 위에서 그린 피봇 테이블을 히트맵으로 표현해봅시다.
plt.figure(figsize=(12, 7))
sns.heatmap(t, cmap="Blues", annot=True ,fmt=".0f")
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='연도'>

# %%
# transpose를 사용하면 행과 열을 바꿔줄 수 있습니ㅏㄷ.
t.T
# Out:
# 연도      2013     2014     2015     2016     2017     2018     2019
# 지역명
# 강원    6230.0   6332.0   6831.0   7011.0   7127.0   7681.0   8142.0
# 경기   10855.0  10509.0  10489.0  11220.0  11850.0  13186.0  14469.0
# 경남    6473.0   6729.0   7646.0   7848.0   8120.0   9019.0   9871.0
# 경북    6168.0   6536.0   7035.0   7361.0   7795.0   8505.0   8857.0
# 광주    6098.0   7588.0   7956.0   8899.0   9464.0   9856.0  11823.0
# 대구    8080.0   8286.0   8707.0  10310.0  11456.0  12076.0  13852.0
# 대전    8321.0   8240.0   8105.0   8502.0   9045.0  10180.0  11778.0
# 부산    8111.0   9180.0   9633.0  10430.0  11578.0  12998.0  13116.0
# 서울   18189.0  18997.0  19283.0  20663.0  21376.0  22889.0  26131.0
# 세종    7601.0   8085.0   8641.0   8860.0   9135.0  10355.0  11079.0
# 울산    8090.0   8362.0   9273.0  10209.0  11345.0  10241.0  10022.0
# 인천   10204.0  10075.0  10277.0  10532.0  10737.0  11274.0  12635.0
# 전남    5678.0   5719.0   6109.0   6489.0   7188.0   7789.0   7902.0
# 전북    6282.0   6362.0   6623.0   6418.0   7058.0   7626.0   8197.0
# 제주    7674.0   7855.0   7465.0   9129.0  10831.0  11891.0  12138.0
# 충남    6365.0   6682.0   7024.0   7331.0   7456.0   8013.0   8607.0
# 충북    6589.0   6620.0   6700.0   6770.0   6763.0   7874.0   7575.0

# %%
# 바뀐 행과 열로 다시 히트맵을 그려보자.
plt.figure(figsize=(12, 7))
sns.heatmap(t.T, cmap="Blues", annot=True ,fmt=".0f")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='지역명'>

# %%
# 그룹화해서 피봇 테이블을 그려보자. ["연도", "지역명"]을 인덱스에 넣고 그려보자.
g = df.groupby(["연도", "지역명"])["평당분양가격"].mean().unstack().round()
g
# Out:
# 지역명       강원       경기      경남      경북       광주       대구       대전       부산  \
# 연도
# 2013  6230.0  10855.0  6473.0  6168.0   6098.0   8080.0   8321.0   8111.0
# 2014  6332.0  10509.0  6729.0  6536.0   7588.0   8286.0   8240.0   9180.0
# 2015  6831.0  10489.0  7646.0  7035.0   7956.0   8707.0   8105.0   9633.0
# 2016  7011.0  11220.0  7848.0  7361.0   8899.0  10310.0   8502.0  10430.0
# 2017  7127.0  11850.0  8120.0  7795.0   9464.0  11456.0   9045.0  11578.0
# 2018  7681.0  13186.0  9019.0  8505.0   9856.0  12076.0  10180.0  12998.0
# 2019  8142.0  14469.0  9871.0  8857.0  11823.0  13852.0  11778.0  13116.0
#
# 지역명        서울       세종       울산       인천      전남      전북       제주      충남  \
# 연도
# 2013  18189.0   7601.0   8090.0  10204.0  5678.0  6282.0   7674.0  6365.0
# 2014  18997.0   8085.0   8362.0  10075.0  5719.0  6362.0   7855.0  6682.0
# 2015  19283.0   8641.0   9273.0  10277.0  6109.0  6623.0   7465.0  7024.0
# 2016  20663.0   8860.0  10209.0  10532.0  6489.0  6418.0   9129.0  7331.0
# 2017  21376.0   9135.0  11345.0  10737.0  7188.0  7058.0  10831.0  7456.0
# 2018  22889.0  10355.0  10241.0  11274.0  7789.0  7626.0  11891.0  8013.0
# 2019  26131.0  11079.0  10022.0  12635.0  7902.0  8197.0  12138.0  8607.0
#
# 지역명       충북
# 연도
# 2013  6589.0
# 2014  6620.0
# 2015  6700.0
# 2016  6770.0
# 2017  6763.0
# 2018  7874.0
# 2019  7575.0

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(g.T, annot = True, fmt=".0f", cmap="Greens")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='지역명'>

# %% [markdown]
# # 2013년 ~ 최근 데이터까지 시각화하기

# %% [markdown]
# ## 연도별 평당분양가격 보기

# %%
# barplot로 그려보자.
sns.barplot(data = df, x = "연도", y = "평당분양가격")
# 전체적으로 꾸준히 상승했다는걸 볼 수 있다.
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
# pointplot으로 그려보자.
plt.figure(figsize=(12, 4))
sns.pointplot(data=df, x="연도", y="평당분양가격", hue="지역명")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=-0.)

# %%
# 지역 중 서울만 barplot으로 그려보자.
df_seoul = df[df["지역명"] == "서울"].copy()
print(df_seoul.shape)

sns.barplot(data=df_seoul, x="연도", y="평당분양가격", color="b")
sns.pointplot(data=df_seoul, x="연도", y="평당분양가격")
# Out:
# (72, 4)
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
# boxplot으로 그려보자.
sns.boxplot(data=df, x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
# boxplot으로 그려보자.
sns.boxenplot(data=df, x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
# violinplot으로 그려보자.
sns.violinplot(data=df, x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
# swarmplot으로 그려보자.
plt.figure(figsize=(12, 3))
sns.swarmplot(data=df, x="연도", y="평당분양가격", hue="지역명")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=-0.)
# Out:
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 41.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 48.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 35.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 39.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 27.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# swarmplot으로 그려보자.
plt.figure(figsize=(12, 3))
sns.violinplot(data=df, x="연도", y="평당분양가격")
sns.swarmplot(data=df, x="연도", y="평당분양가격", hue="지역명")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=-0.)
# Out:
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 56.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 45.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 44.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 지역별 평당분양가격 보기

# %%
# barplot
plt.figure(figsize=(12, 4))
sns.barplot(data = df, x = "지역명", y = "평당분양가격")
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
# boxplot
plt.figure(figsize=(12, 4))
sns.boxplot(data = df, x = "지역명", y = "평당분양가격")
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
# boxenplot
plt.figure(figsize=(12, 4))
sns.boxenplot(data = df, x = "지역명", y = "평당분양가격")
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
# violinplot
plt.figure(figsize=(24, 4))
sns.violinplot(data = df, x = "지역명", y = "평당분양가격")
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
# swarmplot
plt.figure(figsize=(12, 4))
a = sns.swarmplot(data = df, x = "지역명", y = "평당분양가격", hue="연도")
a
# Out:
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 45.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 29.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 38.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 54.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 61.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 68.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 59.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 47.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>
